# %% [markdown]
# # 2. R-squared
# ---
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# - R-squared가 0에 가깝다는 의미는 회귀선의 설명력(Regression line)이 낮다는 의미가 되며, 데이터가 모형에 fit 하지 않음을 뜻한다.
# - 모형의 오차가 작다면 R-squared가 커지게 될 것이고, 모형의 오차가 크다면 R-squared가 작아지게 된다.
# - **baseline model에 비해 현 모형이 얼마나 정확성을 갖는지는 나타내는 척도라고 보면됨**
